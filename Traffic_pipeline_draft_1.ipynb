# %% [markdown]
# ## Step 1: Ingest Data
#
# We will use RESTful API to retrieve traffic camera data from the public City of Calgary website https://data.calgary.ca/Transportation-Transit/Traffic-Cameras/k7p9-kppz/about_data
#
# We will use the python library to help make our requests.

# %%
# !python -V
# Out:
# Python 3.10.12

# %%
#request
import requests
import pandas as pd
import io

api_url = 'https://data.calgary.ca/resource/k7p9-kppz.csv'


response = requests.get(api_url)

if response.status_code == 200:
  data = io.StringIO(response.text)
  df = pd.read_csv(data)
  display(df.head())
else:
  print("Failed to get data")
# Out:
#                                           camera_url quadrant  \
# 0  Camera 158 (http://trafficcam.calgary.ca/loc15...       SW
# 1  Camera 30 (http://trafficcam.calgary.ca/loc29....       SE
# 2  Camera 142 (http://trafficcam.calgary.ca/loc14...       SW
# 3  Camera 90 (http://trafficcam.calgary.ca/loc89....    NW/NE
# 4  Camera 38 (https://trafficcam.calgary.ca/loc37...       NW
#
#                          camera_location                            point
# 0                       26 Ave / 4 St SW  POINT (-114.0716774 51.0296112)
# 1              114 Avenue / 52 Street SE   POINT (-113.958331 50.9504395)
# 2               90 Avenue / 24 Street SW  POINT (-114.1177502 50.9724213)
# 3       Samis Road / Centre Street North  POINT (-114.0624739 51.0549834)
# 4  Crowchild Trail / Shaganappi Trail NW   POINT (-114.149379 51.0988494)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   camera_url       176 non-null    object
#  1   quadrant         176 non-null    object
#  2   camera_location  176 non-null    object
#  3   point            176 non-null    object
# dtypes: object(4)
# memory usage: 5.6+ KB

# %%
#transforming dataframe
df[['Camera_Number', 'URL']] = df['camera_url'].str.extract(r'Camera (\d+) \((http[^\)]+)\)')
df[['longitude', 'latitude']] = df['point'].str.extract(r'POINT \(([^ ]+) ([^ ]+)\)', expand=True)
df['latitude'] = pd.to_numeric(df['latitude'])
df['longitude'] = pd.to_numeric(df['longitude'])
df.drop(columns=['camera_url','point'], inplace = True)
df['Camera_Number'] = df['Camera_Number'].astype(int)
display(df.head())
# Out:
#   quadrant                        camera_location  Camera_Number  \
# 0       SW                       26 Ave / 4 St SW            158
# 1       SE              114 Avenue / 52 Street SE             30
# 2       SW               90 Avenue / 24 Street SW            142
# 3    NW/NE       Samis Road / Centre Street North             90
# 4       NW  Crowchild Trail / Shaganappi Trail NW             38
#
#                                        URL   longitude   latitude
# 0  http://trafficcam.calgary.ca/loc157.jpg -114.071677  51.029611
# 1   http://trafficcam.calgary.ca/loc29.jpg -113.958331  50.950440
# 2  http://trafficcam.calgary.ca/loc141.jpg -114.117750  50.972421
# 3   http://trafficcam.calgary.ca/loc89.jpg -114.062474  51.054983
# 4  https://trafficcam.calgary.ca/loc37.jpg -114.149379  51.098849

# %%
from IPython.display import Image, display


image_url = 'http://trafficcam.calgary.ca/loc29.jpg'

display(Image(url=image_url))

# %%
try:
    from google.colab import drive
    COLAB = True
    print("Note: using Google CoLab")
except:
    print("Note: not using Google CoLab")
    COLAB = False
# Out:
# Note: using Google CoLab

# %%
#cloning git and installing yolov5
import sys
# !rm -rf /content/yolov5 #removing the existing directory
# !git clone https://github.com/ultralytics/yolov5 --tag 6.2  # clone
# !mv /content/6.2 /content/yolov5
# %pip install -qr /content/yolov5/requirements.txt  # install
sys.path.insert(0,'/content/yolov5')

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-294-gdb125a20 Python-3.10.12 torch-2.2.1+cu121 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.6/107.7 GB disk)

# %%
import urllib.request
import shutil
import os
from IPython.display import Image, display




images_dir = "/content/images/"
yolo_output_dir = "/content/yolov5/runs/detect/"

os.makedirs(images_dir, exist_ok=True)
os.makedirs(yolo_output_dir, exist_ok=True)

# !rm -rf {yolo_output_dir}*

failed_downloads = []

for i, row in df.iterrows():
    image_url = row['URL']
    image_name = f"image_{i}.jpg"
    local_img_file = os.path.join(images_dir, image_name)

    try:

        with urllib.request.urlopen(image_url) as response, open(local_img_file, 'wb') as out_file:
            shutil.copyfileobj(response, out_file)
    except urllib.error.HTTPError as e:
        print(f"Failed to download {image_url}: {e.reason}")
        failed_downloads.append((image_url, e.code))
        continue


# run yolo
# !python /content/yolov5/detect.py --weights yolov5s.pt --img 1024 \
  --conf 0.25 --source {images_dir} --name "batch"

output_images_dir = os.path.join(yolo_output_dir, "images")
for image_file in os.listdir(output_images_dir):
    display(Image(filename=os.path.join(output_images_dir, image_file)))

print("Failed downloads:", failed_downloads)
# Out:
# Failed to download http://trafficcam.calgary.ca/loc22.jpg: Not Found
# detect: weights=['yolov5s.pt'], source=/content/images/, data=yolov5/data/coco128.yaml, imgsz=[1024, 1024], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=batch, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-294-gdb125a20 Python-3.10.12 torch-2.2.1+cu121 CPU
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100% 14.1M/14.1M [00:00<00:00, 38.0MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/175 /content/images/image_0.jpg: 768x1024 2 traffic lights, 1049.2ms
# image 2/175 /content/images/image_1.jpg: 768x1024 1 person, 2 traffic lights, 907.4ms
# image 3/175 /content/images/image_10.jpg: 768x1024 5 traffic lights, 892.8ms
# image 4/175 /content/images/image_100.jpg: 768x1024 (no detections), 897.9ms
# image 5/175 /content/images/image_101.jpg: 768x1024 1 train, 1 umbrella, 876.8ms
# image 6/175 /content/images/image_102.jpg: 768x1024 (no detections), 890.2ms
# image 7/175 /content/images/image_103.jpg: 768x1024 1 truck, 1 traffic light, 871.2ms
# image 8/175 /content/images/image_104.jpg: 768x1024 4 cars, 1 train, 1 truck, 1 traffic light, 1319.6ms
# image 9/175 /content/images/image_105.jpg: 768x1024 1 car, 1376.3ms
# image 10/175 /content/images/image_106.jpg: 768x1024 2 cars, 5 traffic lights, 1 stop sign, 892.3ms
# image 11/175 /content/images/image_107.jpg: 768x1024 1 car, 3 traffic lights, 876.7ms
# image 12/175 /content/images/image_108.jpg: 768x1024 (no detections), 864.6ms
# image 13/175 /content/images/image_109.jpg: 768x1024 1 car, 4 traffic lights, 886.8ms
# image 14/175 /content/images/image_11.jpg: 768x1024 (no detections), 866.1ms
# image 15/175 /content/images/image_110.jpg: 768x1024 3 traffic lights, 933.0ms
# image 16/175 /content/images/image_111.jpg: 768x1024 2 clocks, 953.2ms
# image 17/175 /content/images/image_112.jpg: 768x1024 2 persons, 2 cars, 888.3ms
# image 18/175 /content/images/image_113.jpg: 768x1024 1 suitcase, 1 mouse, 1 clock, 856.8ms
# image 19/175 /content/images/image_114.jpg: 768x1024 1 person, 3 cars, 5 traffic lights, 866.0ms
# image 20/175 /content/images/image_115.jpg: 768x1024 3 cars, 3 traffic lights, 949.4ms
# image 21/175 /content/images/image_116.jpg: 768x1024 3 cars, 1 traffic light, 1326.1ms
# image 136/175 /content/images/image_63.jpg: 768x1024 1 train, 1320.8ms
# image 137/175 /content/images/image_64.jpg: 768x1024 5 cars, 2 trucks, 1190.7ms
# image 138/175 /content/images/image_65.jpg: 768x1024 (no detections), 905.9ms
# image 139/175 /content/images/image_66.jpg: 768x1024 (no detections), 932.1ms
# image 140/175 /content/images/image_67.jpg: 768x1024 1 traffic light, 916.0ms
# image 141/175 /content/images/image_68.jpg: 768x1024 (no detections), 863.0ms
# image 142/175 /content/images/image_69.jpg: 768x1024 1 traffic light, 904.1ms
# image 143/175 /content/images/image_7.jpg: 768x1024 4 cars, 879.8ms
# image 144/175 /content/images/image_70.jpg: 768x1024 1 person, 7 cars, 2 traffic lights, 869.6ms
# image 145/175 /content/images/image_71.jpg: 768x1024 (no detections), 887.3ms
# image 146/175 /content/images/image_72.jpg: 768x1024 1 traffic light, 864.3ms
# image 147/175 /content/images/image_73.jpg: 768x1024 2 cars, 1 truck, 4 traffic lights, 843.1ms
# image 148/175 /content/images/image_74.jpg: 768x1024 1 car, 1 train, 1 truck, 1 traffic light, 1092.5ms
# image 149/175 /content/images/image_75.jpg: 768x1024 2 traffic lights, 1307.1ms
# image 150/175 /content/images/image_76.jpg: 768x1024 10 cars, 1 boat, 1111.9ms
# image 151/175 /content/images/image_77.jpg: 768x1024 1 person, 923.4ms
# image 152/175 /content/images/image_78.jpg: 768x1024 1 train, 1 traffic light, 883.1ms
# image 153/175 /content/images/image_79.jpg: 768x1024 9 cars, 7 traffic lights, 865.8ms
# image 154/175 /content/images/image_8.jpg: 768x1024 1 car, 878.0ms
# image 155/175 /content/images/image_80.jpg: 768x1024 1 train, 4 traffic lights, 899.5ms
# image 156/175 /content/images/image_81.jpg: 768x1024 4 traffic lights, 918.2ms
# image 157/175 /content/images/image_82.jpg: 768x1024 1 train, 4 traffic lights, 868.8ms
# image 158/175 /content/images/image_83.jpg: 768x1024 5 traffic lights, 852.2ms
# image 159/175 /content/images/image_84.jpg: 768x1024 2 traffic lights, 867.9ms
# image 160/175 /content/images/image_85.jpg: 768x1024 (no detections), 864.7ms
# image 161/175 /content/images/image_86.jpg: 768x1024 1 car, 1 traffic light, 1172.6ms
# image 162/175 /content/images/image_87.jpg: 768x1024 2 cars, 1 traffic light, 1309.6ms
# image 163/175 /content/images/image_88.jpg: 768x1024 (no detections), 1060.4ms
# image 164/175 /content/images/image_89.jpg: 768x1024 4 cars, 3 traffic lights, 876.3ms
# image 165/175 /content/images/image_9.jpg: 768x1024 1 car, 1 motorcycle, 862.6ms
# image 166/175 /content/images/image_90.jpg: 768x1024 5 cars, 879.6ms
# image 167/175 /content/images/image_91.jpg: 768x1024 6 cars, 1 bus, 2 traffic lights, 889.0ms
# image 168/175 /content/images/image_92.jpg: 768x1024 1 person, 2 traffic lights, 887.9ms
# image 169/175 /content/images/image_93.jpg: 768x1024 3 traffic lights, 868.6ms
# image 170/175 /content/images/image_94.jpg: 768x1024 1 traffic light, 860.9ms
# image 171/175 /content/images/image_95.jpg: 768x1024 1 car, 1 stop sign, 871.6ms
# image 172/175 /content/images/image_96.jpg: 768x1024 4 cars, 2 traffic lights, 869.0ms
# image 173/175 /content/images/image_97.jpg: 768x1024 (no detections), 862.4ms
# image 174/175 /content/images/image_98.jpg: 768x1024 1 car, 1195.3ms
# image 175/175 /content/images/image_99.jpg: 768x1024 1 traffic light, 1338.6ms
# Speed: 2.8ms pre-process, 959.6ms inference, 9.3ms NMS per image at shape (1, 3, 1024, 1024)
# Results saved to yolov5/runs/detect/batch
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-2fc21caf61ce> in <cell line: 42>()
#      40 # Adjust path according to your YOLO version and output directory structure
#      41 output_images_dir = os.path.join(yolo_output_dir, "images")
# ---> 42 for image_file in os.listdir(output_images_dir):
#      43     display(Image(filename=os.path.join(output_images_dir, image_file)))
#      44 # Optional: handle or log failed downloads after the loop
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/yolov5/runs/detect/images'

# %% [markdown]
# Sets up the directories for storing images and YOLOv5 outputs.
# Clears the YOLOv5 detect output directory to avoid clutter from previous runs.
# Downloads the specified image from your DataFrame and saves it locally.
# Runs the YOLOv5 model on the saved image to perform object detection.
# Finds the latest output directory created by YOLOv5 (since YOLOv5 creates a new directory for each run) and constructs the path to the detected image.
# Displays the image with detected objects using IPython's Image display function.

# %%
import torch
import os
import pandas as pd

# Load the YOLOv5 model
yolo_model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)


images_dir = "/content/images/"

all_detections = []


for image_name in os.listdir(images_dir):
    local_img_file = os.path.join(images_dir, image_name)
    results = yolo_model(local_img_file)
    dt = results.pandas().xyxy[0]

    detection_counts = dt['name'].value_counts().reset_index()
    detection_counts.columns = ['name', 'count']

    detections_pivot = detection_counts.pivot(index=None, columns='name', values='count').fillna(0).astype(int)


    if detections_pivot.empty:
        detections_pivot = pd.DataFrame([{}])

    camera_number = int(image_name.split('_')[-1].split('.')[0]) + 1
    detections_pivot['Camera Number'] = camera_number

    all_detections.append(detections_pivot)

all_detections_df = pd.concat(all_detections, ignore_index=True)

all_detections_df = all_detections_df.fillna(0)

cols = list(all_detections_df)
cols.insert(0, cols.pop(cols.index('Camera Number')))
all_detections_df = all_detections_df.loc[:, cols]

consolidated_detections_df = all_detections_df.groupby('Camera Number').sum().reset_index()
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 v7.0-294-gdb125a20 Python-3.10.12 torch-2.2.1+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
df_detections= consolidated_detections_df.filter(items=['Camera Number','car', 'truck','bus'])
final_detection_table = pd.merge(df_detections, df, how='inner', left_on ='Camera Number', right_on='Camera_Number')
final_detection_table.head(30)
# Out:
#     Camera Number  car  truck  bus quadrant  \
# 0               1  0.0    0.0  0.0    SW/SE
# 1               2  0.0    0.0  0.0       SE
# 2               3  2.0    0.0  0.0       SE
# 3               4  2.0    0.0  0.0       NE
# 4               5  0.0    0.0  0.0       NW
# 5               6  1.0    0.0  0.0       SW
# 6               7  0.0    0.0  0.0       SW
# 7               8  4.0    0.0  0.0       SE
# 8               9  2.0    0.0  0.0    SW/SE
# 9              10  1.0    0.0  1.0    SW/SE
# 10             11  0.0    0.0  1.0       SE
# 11             12  0.0    0.0  0.0    SW/SE
# 12             13  0.0    0.0  0.0       NE
# 13             14  0.0    0.0  0.0       SW
# 14             15  0.0    0.0  0.0       SE
# 15             16  0.0    0.0  0.0       SW
# 16             17  0.0    0.0  0.0       NW
# 17             18  2.0    0.0  0.0       SE
# 18             19  3.0    0.0  0.0       SE
# 19             20  0.0    0.0  0.0       SE
# 20             21  0.0    0.0  0.0       SE
# 21             22  0.0    0.0  0.0       SE
# 22             23  0.0    0.0  0.0       NW
# 23             24  2.0    0.0  0.0       SW
# 24             25  4.0    0.0  0.0       SW
# 25             26  0.0    0.0  0.0       SE
# 26             27  2.0    0.0  0.0       SW
# 27             28  0.0    0.0  0.0    SW/SE
# 28             29  0.0    0.0  0.0       SW
# 29             30  0.0    0.0  0.0       SE
#
#                             camera_location  Camera_Number  \
# 0          Glenmore Trail / Macleod Trail S              1
# 1            Peigan Trail / Barlow Trail SE              2
# 2               50 Avenue / Barlow Trail SE              3
# 3              Memorial Drive / 52 Street E              4
# 4      Kensington Road / Crowchild Trail NW              5
# 5                    4 Avenue / 9 Street SW              6
# 6    Glenmore Trail / Elbow Drive SW (East)              7
# 7               Stoney Trail / 52 Street SE              8
# 8          Heritage Drive / Macleod Trail S              9
# 9          Bannister Road / Macleod Trail S             10
# 10           130 Avenue / Deerfoot Trail SE             11
# 11             149 Avenue / Macleod Trail S             12
# 12             McKnight Blvd / 52 Street NE             13
# 13                  8 Avenue / 11 Street SW             14
# 14                 17 Avenue / 28 Street SE             15
# 15      Glenmore Trail / Crowchild Trail SW             16
# 16           24 Avenue / Crowchild Trail NW             17
# 17       Memorial Drive / Deerfoot Trail SE             18
# 18            17 Avenue / Deerfoot Trail SE             19
# 19            22 Avenue / Deerfoot Trail SE             20
# 20            34 Avenue / Deerfoot Trail SE             21
# 21                 50 Avenue / 52 Street SE             22
# 22      Crowchild Trail / Nosehill Drive NW             23
# 23           Southland Drive / 14 Street SW             24
# 24            Heritage Drive / 14 Street SW             25
# 25              Stoney Trail / 88 Street SE             26
# 26      5 Avenue btw 1 Street & 2 Street SW             27
# 27  Glenmore Trail / Macleod Trail S (West)             28
# 28            Glenmore Trail / 1A Street SW             29
# 29                114 Avenue / 52 Street SE             30
#
#                                        URL   longitude   latitude
# 0    http://trafficcam.calgary.ca/loc0.jpg -114.071585  50.993989
# 1    http://trafficcam.calgary.ca/loc1.jpg -114.002689  51.014972
# 2    http://trafficcam.calgary.ca/loc2.jpg -114.001845  51.008623
# 3    http://trafficcam.calgary.ca/loc3.jpg -113.955818  51.053253
# 4    http://trafficcam.calgary.ca/loc4.jpg -114.118088  51.052487
# 5    http://trafficcam.calgary.ca/loc5.jpg -114.083522  51.049960
# 6    http://trafficcam.calgary.ca/loc6.jpg -114.084236  50.993916
# 7    http://trafficcam.calgary.ca/loc7.jpg -113.953747  50.904018
# 8    http://trafficcam.calgary.ca/loc8.jpg -114.071775  50.979387
# 9    http://trafficcam.calgary.ca/loc9.jpg -114.071651  50.925155
# 10  http://trafficcam.calgary.ca/loc10.jpg -113.975055  50.931961
# 11  http://trafficcam.calgary.ca/loc11.jpg -114.070306  50.918887
# 12  http://trafficcam.calgary.ca/loc12.jpg -113.958210  51.095884
# 13  http://trafficcam.calgary.ca/loc13.jpg -114.088641  51.046258
# 14  http://trafficcam.calgary.ca/loc14.jpg -113.993084  51.037748
# 15  http://trafficcam.calgary.ca/loc15.jpg -114.118048  51.000038
# 16  http://trafficcam.calgary.ca/loc16.jpg -114.118219  51.074189
# 17  http://trafficcam.calgary.ca/loc17.jpg -114.018169  51.047852
# 18  http://trafficcam.calgary.ca/loc18.jpg -114.005086  51.036803
# 19  http://trafficcam.calgary.ca/loc19.jpg -113.994715  51.033775
# 20  http://trafficcam.calgary.ca/loc20.jpg -113.999841  51.023285
# 21  http://trafficcam.calgary.ca/loc21.jpg -113.958422  51.008880
# 22  http://trafficcam.calgary.ca/loc22.jpg -114.202451  51.120065
# 23  http://trafficcam.calgary.ca/loc23.jpg -114.095354  50.961572
# 24  http://trafficcam.calgary.ca/loc24.jpg -114.094847  50.979530
# 25  http://trafficcam.calgary.ca/loc25.jpg -113.907277  50.906454
# 26  http://trafficcam.calgary.ca/loc26.jpg -114.066420  51.048485
# 27  http://trafficcam.calgary.ca/loc27.jpg -114.071551  50.993918
# 28  http://trafficcam.calgary.ca/loc28.jpg -114.067332  50.994360
# 29  http://trafficcam.calgary.ca/loc29.jpg -113.958331  50.950440

# %%
timeapi_url = 'https://www.timeapi.io/api/Time/current/zone?timeZone=America/Edmonton'

response = requests.get(timeapi_url)
time_data = response.json()

current_date = time_data['date']
current_time = time_data['time']
current_dayofweek = time_data['dayOfWeek']
df_time =pd.DataFrame({
    'Current Date':[current_date],
    'Current Time':[current_time],
    'Day of Week' :[current_dayofweek]
})

final_detection_table = final_detection_table.assign(
        **{'Current Date': current_date, 'Current Time': current_time, 'Day of Week': current_dayofweek}
    )

final_detection_table
# Out:
#      Camera Number  car  truck  bus quadrant  ...   longitude   latitude  \
# 0                1  0.0    0.0  0.0    SW/SE  ... -114.071585  50.993989
# 1                2  0.0    0.0  0.0       SE  ... -114.002689  51.014972
# 2                3  2.0    0.0  0.0       SE  ... -114.001845  51.008623
# 3                4  2.0    0.0  0.0       NE  ... -113.955818  51.053253
# 4                5  0.0    0.0  0.0       NW  ... -114.118088  51.052487
# ..             ...  ...    ...  ...      ...  ...         ...        ...
# 169            172  0.0    0.0  0.0       NE  ... -113.919492  51.154137
# 170            173  2.0    0.0  0.0       NE  ... -114.035252  51.142317
# 171            174  0.0    0.0  0.0       SW  ... -114.211172  51.066886
# 172            175  0.0    0.0  0.0       SW  ... -114.210956  51.038191
# 173            176  0.0    0.0  0.0       SE  ... -113.941802  50.884967
#
#     Current Date  Current Time  Day of Week
# 0     03/19/2024         23:39      Tuesday
# 1     03/19/2024         23:39      Tuesday
# 2     03/19/2024         23:39      Tuesday
# 3     03/19/2024         23:39      Tuesday
# 4     03/19/2024         23:39      Tuesday
# ..           ...           ...          ...
# 169   03/19/2024         23:39      Tuesday
# 170   03/19/2024         23:39      Tuesday
# 171   03/19/2024         23:39      Tuesday
# 172   03/19/2024         23:39      Tuesday
# 173   03/19/2024         23:39      Tuesday
#
# [174 rows x 13 columns]

# %%
final_detection_table.to_csv('Traffic_detection.csv', index=False)
